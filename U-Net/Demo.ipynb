# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %run "./Unet/train.py"
# Out:
# The device being used is: cuda
#
# Training Started.....
# /usr/local/lib/python3.6/dist-packages/torchvision/transforms/functional.py:109: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   img = torch.as_tensor(np.asarray(pic))
# The training images
# The original masks
# Predicted masks
# Epoch 0 : Lr (0.0001)
# 		 Training Loss: 2.1146,  Training IoU: 0.143,
# 		 Validation Loss: 1.4197,  Validation IoU: 0.300
# Validation loss decreased (inf --> 1.419686). Saving model ...
#
# Epoch 1 : Lr (0.0001)
# 		 Training Loss: 0.7049,  Training IoU: 0.381,
# ...

# %%
# !cp -r "./Unet" "./drive/My Drive/"

# %%
# %run "./Unet/test.py"
